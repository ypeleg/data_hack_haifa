# %% [markdown]
# ## **House Prices: Beginner ML Tutorial. Chapter 1**

# %% [markdown]
# ![](https://www.reno.gov/Home/ShowImage?id=7739&t=635620964226970000)
#
# **Competition Description from Kaggle**
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# **Data description**
# This is a detailed description of the 79 features and their entries, quite important for this competition.
# You can download the txt file here: [**download**](https://www.kaggle.com/c/5407/download/data_description.txt)

# %% [markdown]
# **References**
#
# * **[Kaggle: Comprehensive data exploration with Python](https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python)**
# * **[Udemy: Python for Data Science and Machine Learning Bootcamp](https://www.udemy.com/python-for-data-science-and-machine-learning-bootcamp/)**
# * **[Data School: Machine learning in Python with scikit-learn](https://www.youtube.com/playlist?list=PL5-da3qGB5ICeMbQuqbbCOQWcS6OYBr5A)**

# %% [markdown]
# # Chapter 1 - Intro To Pandas

# %%
import pandas

# %%
pandas.__version__
# Out:
# u'0.23.4'

# %%
pandas.read_csv('../data/house_prices.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
df = pandas.read_csv('../data/house_prices.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
import pandas as pd

# %%
# from pandas import * ## Do not do this

# %%
df = pd.read_csv('../data/house_prices.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
df.values
# Out:
# array([[1, 60, 'RL', ..., 'WD', 'Normal', 208500],
#        [2, 20, 'RL', ..., 'WD', 'Normal', 181500],
#        [3, 60, 'RL', ..., 'WD', 'Normal', 223500],
#        ...,
#        [1458, 70, 'RL', ..., 'WD', 'Normal', 266500],
#        [1459, 20, 'RL', ..., 'WD', 'Normal', 142125],
#        [1460, 20, 'RL', ..., 'WD', 'Normal', 147500]], dtype=object)

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
street = df['Street']

# %%
type(street)
# Out:
# pandas.core.series.Series

# %%
street = df[['Street']]

# %%
type(street)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.drop(['Street'], axis='columns').head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Alley LotShape LandContour  \
# 0   1          60       RL         65.0     8450   NaN      Reg         Lvl
# 1   2          20       RL         80.0     9600   NaN      Reg         Lvl
# 2   3          60       RL         68.0    11250   NaN      IR1         Lvl
# 3   4          70       RL         60.0     9550   NaN      IR1         Lvl
# 4   5          60       RL         84.0    14260   NaN      IR1         Lvl
#
#   Utilities LotConfig    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0    AllPub    Inside    ...            0    NaN   NaN         NaN       0
# 1    AllPub       FR2    ...            0    NaN   NaN         NaN       0
# 2    AllPub    Inside    ...            0    NaN   NaN         NaN       0
# 3    AllPub    Corner    ...            0    NaN   NaN         NaN       0
# 4    AllPub       FR2    ...            0    NaN   NaN         NaN       0
#
#   MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Wait a second..

# %%
df.drop(['Street'], axis='columns', inplace=True)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Alley LotShape LandContour  \
# 0   1          60       RL         65.0     8450   NaN      Reg         Lvl
# 1   2          20       RL         80.0     9600   NaN      Reg         Lvl
# 2   3          60       RL         68.0    11250   NaN      IR1         Lvl
# 3   4          70       RL         60.0     9550   NaN      IR1         Lvl
# 4   5          60       RL         84.0    14260   NaN      IR1         Lvl
#
#   Utilities LotConfig    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0    AllPub    Inside    ...            0    NaN   NaN         NaN       0
# 1    AllPub       FR2    ...            0    NaN   NaN         NaN       0
# 2    AllPub    Inside    ...            0    NaN   NaN         NaN       0
# 3    AllPub    Corner    ...            0    NaN   NaN         NaN       0
# 4    AllPub       FR2    ...            0    NaN   NaN         NaN       0
#
#   MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df = pd.read_csv('../data/house_prices.csv')

# %%
df.loc[0]
# Out:
# Id                     1
# MSSubClass            60
# MSZoning              RL
# LotFrontage           65
# LotArea             8450
# Street              Pave
# Alley                NaN
# LotShape             Reg
# LandContour          Lvl
# Utilities         AllPub
# LotConfig         Inside
# LandSlope            Gtl
# Neighborhood     CollgCr
# Condition1          Norm
# Condition2          Norm
# BldgType            1Fam
# HouseStyle        2Story
# OverallQual            7
# OverallCond            5
# YearBuilt           2003
# YearRemodAdd        2003
# RoofStyle          Gable
# RoofMatl         CompShg
# Exterior1st      VinylSd
# Exterior2nd      VinylSd
# MasVnrType       BrkFace
# MasVnrArea           196
# ExterQual             Gd
# ExterCond             TA
# Foundation         PConc
#                   ...
# BedroomAbvGr           3
# KitchenAbvGr           1
# KitchenQual           Gd
# TotRmsAbvGrd           8
# Functional           Typ
# Fireplaces             0
# ...

# %%
df.loc[[0, 1]]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
df.iloc[0]
# Out:
# Id                     1
# MSSubClass            60
# MSZoning              RL
# LotFrontage           65
# LotArea             8450
# Street              Pave
# Alley                NaN
# LotShape             Reg
# LandContour          Lvl
# Utilities         AllPub
# LotConfig         Inside
# LandSlope            Gtl
# Neighborhood     CollgCr
# Condition1          Norm
# Condition2          Norm
# BldgType            1Fam
# HouseStyle        2Story
# OverallQual            7
# OverallCond            5
# YearBuilt           2003
# YearRemodAdd        2003
# RoofStyle          Gable
# RoofMatl         CompShg
# Exterior1st      VinylSd
# Exterior2nd      VinylSd
# MasVnrType       BrkFace
# MasVnrArea           196
# ExterQual             Gd
# ExterCond             TA
# Foundation         PConc
#                   ...
# BedroomAbvGr           3
# KitchenAbvGr           1
# KitchenQual           Gd
# TotRmsAbvGrd           8
# Functional           Typ
# Fireplaces             0
# ...

# %%
df.iloc[-1]
# Out:
# Id                  1460
# MSSubClass            20
# MSZoning              RL
# LotFrontage           75
# LotArea             9937
# Street              Pave
# Alley                NaN
# LotShape             Reg
# LandContour          Lvl
# Utilities         AllPub
# LotConfig         Inside
# LandSlope            Gtl
# Neighborhood     Edwards
# Condition1          Norm
# Condition2          Norm
# BldgType            1Fam
# HouseStyle        1Story
# OverallQual            5
# OverallCond            6
# YearBuilt           1965
# YearRemodAdd        1965
# RoofStyle          Gable
# RoofMatl         CompShg
# Exterior1st      HdBoard
# Exterior2nd      HdBoard
# MasVnrType          None
# MasVnrArea             0
# ExterQual             Gd
# ExterCond             TA
# Foundation        CBlock
#                   ...
# BedroomAbvGr           3
# KitchenAbvGr           1
# KitchenQual           TA
# TotRmsAbvGrd           6
# Functional           Typ
# Fireplaces             0
# ...

# %%
subset = df.loc[:, ['Street', 'YrSold']]

# %%
subset.head()
# Out:
#   Street  YrSold
# 0   Pave    2008
# 1   Pave    2007
# 2   Pave    2008
# 3   Pave    2006
# 4   Pave    2008

# %%
subset = df.iloc[:, [2, 4]]

# %%
subset.head()
# Out:
#   MSZoning  LotArea
# 0       RL     8450
# 1       RL     9600
# 2       RL    11250
# 3       RL     9550
# 4       RL    14260

# %%
df.loc[df['YrSold'] == 2008].shape
# Out:
# (304, 81)

# %%
df['YrSold'] == 2008
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
# 5       False
# 6       False
# 7       False
# 8        True
# 9        True
# 10       True
# 11      False
# 12       True
# 13      False
# 14       True
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22       True
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29       True
#         ...
# 1430    False
# 1431    False
# 1432    False
# 1433     True
# 1434    False
# 1435     True
# 1436    False
# 1437     True
# 1438    False
# 1439    False
# 1440     True
# 1441     True
# 1442    False
# 1443    False
# 1444    False
# 1445    False
# 1446    False
# 1447    False
# 1448    False
# 1449    False
# 1450    False
# 1451    False
# 1452    False
# 1453    False
# 1454    False
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459     True
# ...

# %%
df.loc[(df['YrSold'] == 2008) & (df['Street'] == 'Pave')]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.groupby('YrSold')['LotArea'].mean()
# Out:
# YrSold
# 2006    10489.458599
# 2007    10863.686930
# 2008    10587.687500
# 2009    10294.248521
# 2010    10220.645714
# Name: LotArea, dtype: float64

# %%
import numpy as np
df.groupby('YrSold')['LotArea'].agg(np.mean)
# Out:
# YrSold
# 2006    10489.458599
# 2007    10863.686930
# 2008    10587.687500
# 2009    10294.248521
# 2010    10220.645714
# Name: LotArea, dtype: float64

# %%
df.groupby(['YrSold', 'Street'])[['LotArea', 'MoSold']].agg(np.mean).reset_index()
# Out:
#    YrSold Street       LotArea    MoSold
# 0    2006   Pave  10489.458599  6.487261
# 1    2007   Grvl  23487.000000  5.000000
# 2    2007   Pave  10786.480122  6.620795
# 3    2008   Grvl  91330.000000  8.000000
# 4    2008   Pave  10052.970199  6.536424
# 5    2009   Pave  10294.248521  6.718935
# 6    2010   Grvl   8592.000000  5.500000
# 7    2010   Pave  10239.473988  4.312139

# %%
import pandas as pd

# %%
s = pd.Series(['pizza', 42])

# %%
s
# Out:
# 0    pizza
# 1       42
# dtype: object

# %%
s = pd.Series(['pizza', 42], index=['food', 'number'])

# %%
s
# Out:
# food      pizza
# number       42
# dtype: object

# %%
s.loc['food']
# Out:
# 'pizza'

# %%
s.iloc[0]
# Out:
# 'pizza'

# %%
scientists = pd.DataFrame({
    'name': ['Franklin', 'Gosset'],
    'job': ['chem', 'stats']
})

# %%
scientists
# Out:
#      job      name
# 0   chem  Franklin
# 1  stats    Gosset

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
df['LotFrontage'].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
df['LotFrontage'] * df['LotFrontage']
# Out:
# 0        4225.0
# 1        6400.0
# 2        4624.0
# 3        3600.0
# 4        7056.0
# 5        7225.0
# 6        5625.0
# 7           NaN
# 8        2601.0
# 9        2500.0
# 10       4900.0
# 11       7225.0
# 12          NaN
# 13       8281.0
# 14          NaN
# 15       2601.0
# 16          NaN
# 17       5184.0
# 18       4356.0
# 19       4900.0
# 20      10201.0
# 21       3249.0
# 22       5625.0
# 23       1936.0
# 24          NaN
# 25      12100.0
# 26       3600.0
# 27       9604.0
# 28       2209.0
# 29       3600.0
#          ...
# 1430     3600.0
# 1431        NaN
# 1432     3600.0
# 1433     8649.0
# 1434     6400.0
# 1435     6400.0
# 1436     3600.0
# 1437     9216.0
# 1438     8100.0
# 1439     6400.0
# 1440     6241.0
# 1441        NaN
# 1442     7225.0
# 1443        NaN
# 1444     3969.0
# 1445     4900.0
# 1446        NaN
# 1447     6400.0
# 1448     4900.0
# 1449      441.0
# 1450     3600.0
# 1451     6084.0
# 1452     1225.0
# 1453     8100.0
# ...

# %%
df['LotFrontage'] * 2
# Out:
# 0       130.0
# 1       160.0
# 2       136.0
# 3       120.0
# 4       168.0
# 5       170.0
# 6       150.0
# 7         NaN
# 8       102.0
# 9       100.0
# 10      140.0
# 11      170.0
# 12        NaN
# 13      182.0
# 14        NaN
# 15      102.0
# 16        NaN
# 17      144.0
# 18      132.0
# 19      140.0
# 20      202.0
# 21      114.0
# 22      150.0
# 23       88.0
# 24        NaN
# 25      220.0
# 26      120.0
# 27      196.0
# 28       94.0
# 29      120.0
#         ...
# 1430    120.0
# 1431      NaN
# 1432    120.0
# 1433    186.0
# 1434    160.0
# 1435    160.0
# 1436    120.0
# 1437    192.0
# 1438    180.0
# 1439    160.0
# 1440    158.0
# 1441      NaN
# 1442    170.0
# 1443      NaN
# 1444    126.0
# 1445    140.0
# 1446      NaN
# 1447    160.0
# 1448    140.0
# 1449     42.0
# 1450    120.0
# 1451    156.0
# 1452     70.0
# 1453    180.0
# 1454    124.0
# 1455    124.0
# 1456    170.0
# 1457    132.0
# 1458    136.0
# 1459    150.0
# ...

# %%
df['lot_doubled'] = df['LotFrontage'] * 2

# %% [markdown]
# # Ex1 - Knowing your Data

# %% [markdown]
# We are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/ypeleg/data_hack_haifa/data/house_prices.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
path = '../data/house_prices.csv'
# path = 'https://raw.githubusercontent.com/ypeleg/data_hack_haifa/data/house_prices.csv'
df = pd.read_csv(path)

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
df.shape[0]
# Out:
# 1460

# %%
# Solution 2
df.info() # entries <= 4622 observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 81

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
df.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
# ...

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %% [markdown]
# #### Step 8.1. See the first 25 entries

# %%
df.head(25)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %% [markdown]
# #### Step 8.2. See the last 10 entries

# %%
df.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# ...

# %% [markdown]
# #### Step 8.3. What is the number of observations in the dataset?

# %%
df.shape[0]
# Out:
# 1460

# %% [markdown]
# #### Step 8.4. What is the number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 81

# %% [markdown]
# #### Step 8.5. Print the name of all the columns.

# %%
df.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
# ...

# %% [markdown]
# #### Step 8.6. How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %% [markdown]
# #### Step 8.7. What is the data type of each column?

# %%
df.dtypes
# Out:
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %% [markdown]
# #### Step 8.8. Print only the Heating column

# %%
df.Heating 

#OR

df['Heating']
# Out:
# 0       GasA
# 1       GasA
# 2       GasA
# 3       GasA
# 4       GasA
# 5       GasA
# 6       GasA
# 7       GasA
# 8       GasA
# 9       GasA
# 10      GasA
# 11      GasA
# 12      GasA
# 13      GasA
# 14      GasA
# 15      GasA
# 16      GasA
# 17      GasA
# 18      GasA
# 19      GasA
# 20      GasA
# 21      GasA
# 22      GasA
# 23      GasA
# 24      GasA
# 25      GasA
# 26      GasA
# 27      GasA
# 28      GasA
# 29      GasA
#         ...
# 1430    GasA
# 1431    GasA
# 1432    GasA
# 1433    GasA
# 1434    GasA
# 1435    GasA
# 1436    GasA
# 1437    GasA
# 1438    GasA
# 1439    GasA
# 1440    GasA
# 1441    GasA
# 1442    GasA
# 1443    Grav
# 1444    GasA
# 1445    GasA
# 1446    GasA
# 1447    GasA
# 1448    GasA
# 1449    GasA
# 1450    GasA
# 1451    GasA
# 1452    GasA
# 1453    GasA
# 1454    GasA
# 1455    GasA
# 1456    GasA
# 1457    GasA
# 1458    GasA
# 1459    GasA
# Name: Heating, Length: 1460, dtype: object

# %% [markdown]
# #### Step 8.9. How many different Heatings there are in this dataset?

# %%
df.Heating.nunique()
# Out:
# 6

# %% [markdown]
# #### Step 8.10. What is the most frequent occupation?

# %%
df.Heating.value_counts().head()
# Out:
# GasA    1428
# GasW      18
# Grav       7
# Wall       4
# OthW       2
# Name: Heating, dtype: int64

# %% [markdown]
# #### Step 8.11. Summarize the DataFrame.

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# #### Step 8.12. Summarize all the columns

# %%
df.describe(include = "all") #Notice: By default, only the numeric columns are returned.
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# #### Step 8.13. Summarize only the Heating column

# %%
df.Heating.describe()
# Out:
# count     1460
# unique       6
# top       GasA
# freq      1428
# Name: Heating, dtype: object

# %% [markdown]
# #### Step 8.14. What is the mean LotArea of houses?

# %%
round(df.LotArea.mean())
# Out:
# 10517.0

# %% [markdown]
# #### Step 8.15. What is the Heating with least occurrence?

# %%
df.Heating.value_counts().tail()
# Out:
# GasW     18
# Grav      7
# Wall      4
# OthW      2
# Floor     1
# Name: Heating, dtype: int64

# %% [markdown]
# ### Step 9. Which street is the most expensive?

# %%
c = df.groupby('Street')
c = c.sum()
c = c.sort_values(['SalePrice'], ascending=False)
c.head()
# Out:
#              Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# Street
# Pave    1062498       82630      83703.0  15107751         8876         8111
# Grvl       4032         440        427.0    246818           29           29
#
#         YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      \
# Street                                                     ...
# Pave      2866283       2886121    150221.0      644386    ...
# Grvl        11768         11783       330.0        3328    ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Street
# Pave        136821        67809          32053       4978        21726
# Grvl           776          315              0          0          263
#
#         PoolArea  MiscVal  MoSold   YrSold  SalePrice
# Street
# Pave        4028    62180    9193  2919361  263363803
# Grvl           0     1314      37    12050     781143
#
# [2 rows x 38 columns]

# %%
c.iloc[0].name
# Out:
# 'Pave'

# %% [markdown]
# ### Step 10. For the most-expensive street, what is the avg price of house?

# %%
c = df.groupby('Street')
c = c.sum()
c = c.sort_values(['SalePrice'], ascending=False)
street_name = c.iloc[0].name
expensive = df[df['Street'] == street_name]
expensive['SalePrice'].mean()
# Out:
# 181130.53851444292

# %% [markdown]
# ### Step 11. What is the most frequent SaleCondition?

# %%
c = df.groupby('SaleCondition').count()
c.head()
# Out:
#                  Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  \
# SaleCondition
# Abnorml         101         101       101           84      101     101
# AdjLand           4           4         4            4        4       4
# Alloca           12          12        12           10       12      12
# Family           20          20        20           18       20      20
# Normal         1198        1198      1198          961     1198    1198
#
#                Alley  LotShape  LandContour  Utilities    ...      \
# SaleCondition                                             ...
# Abnorml           10       101          101        101    ...
# AdjLand            0         4            4          4    ...
# Alloca             0        12           12         12    ...
# Family             3        20           20         20    ...
# Normal            71      1198         1198       1198    ...
#
# ...

# %% [markdown]
# ### Step 12. What is the total LotArea of the data?

# %%
df.LotArea.sum()
# Out:
# 15354569

# %% [markdown]
# ### Step 13. How many SaleCondition are there?

# %%
df.SaleCondition.value_counts().count()
# Out:
# 6

# %% [markdown]
# ### Step 14. Print only the column MSSubClass

# %%
df['MSSubClass']
# Out:
# 0        60
# 1        20
# 2        60
# 3        70
# 4        60
# 5        50
# 6        20
# 7        60
# 8        50
# 9       190
# 10       20
# 11       60
# 12       20
# 13       20
# 14       20
# 15       45
# 16       20
# 17       90
# 18       20
# 19       20
# 20       60
# 21       45
# 22       20
# 23      120
# 24       20
# 25       20
# 26       20
# 27       20
# 28       20
# 29       30
#        ...
# 1430     60
# 1431    120
# 1432     30
# 1433     60
# 1434     20
# 1435     20
# 1436     20
# 1437     20
# 1438     20
# 1439     60
# 1440     70
# 1441    120
# 1442     60
# 1443     30
# 1444     20
# 1445     85
# 1446     20
# 1447     60
# 1448     50
# 1449    180
# 1450     90
# 1451     20
# 1452    180
# 1453     20
# 1454     20
# 1455     60
# 1456     20
# 1457     70
# 1458     20
# 1459     20
# Name: MSSubClass, Length: 1460, dtype: int64

# %% [markdown]
# ### Step 15. Print the columns 'MSSubClass' and 'LotFrontage'

# %%
df[['MSSubClass', 'LotFrontage']]
# Out:
#       MSSubClass  LotFrontage
# 0             60         65.0
# 1             20         80.0
# 2             60         68.0
# 3             70         60.0
# 4             60         84.0
# 5             50         85.0
# 6             20         75.0
# 7             60          NaN
# 8             50         51.0
# 9            190         50.0
# 10            20         70.0
# 11            60         85.0
# 12            20          NaN
# 13            20         91.0
# 14            20          NaN
# 15            45         51.0
# 16            20          NaN
# 17            90         72.0
# 18            20         66.0
# 19            20         70.0
# 20            60        101.0
# 21            45         57.0
# 22            20         75.0
# 23           120         44.0
# 24            20          NaN
# 25            20        110.0
# 26            20         60.0
# 27            20         98.0
# 28            20         47.0
# 29            30         60.0
# ...

# %% [markdown]
# ### Step 16. Print the name of all the columns.

# %%
df.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
# ...

# %% [markdown]
# ### Step 17. Select the 'LotFrontage', 'size' and 'MSSubClass' columns where SaleCondition is Abnorml

# %%
# Select all rows with the index label "Maine" and "Alaska"
df.loc[df['SaleCondition']=='Abnorml' , ["LotFrontage","MSSubClass"]]
# Out:
#       LotFrontage  MSSubClass
# 3            60.0          70
# 8            51.0          50
# 19           70.0          20
# 38           68.0          20
# 40           84.0          20
# 46           48.0          50
# 56           24.0         160
# 88          105.0          50
# 91           85.0          20
# 98           85.0          30
# 113           NaN          20
# 129          69.0          20
# 144          70.0          90
# 197         174.0          75
# 198          92.0          75
# 223          70.0          20
# 225          21.0         160
# 226          82.0          60
# 257          68.0          20
# 303          70.0          20
# 351           NaN         120
# 358          92.0          80
# 387          72.0          80
# 393           NaN          30
# 398          60.0          30
# 403          93.0          60
# 410          68.0          20
# 430          21.0         160
# 431          60.0          50
# 456          34.0          70
# ...

# %% [markdown]
# ### Step 18. Select the rows 3 to 7 and the columns 3 to 6

# %%
df.iloc[3:7, 3:6]
# Out:
#    LotFrontage  LotArea Street
# 3         60.0     9550   Pave
# 4         84.0    14260   Pave
# 5         85.0    14115   Pave
# 6         75.0    10084   Pave

# %% [markdown]
# ### Step 19. Select every row after the fourth row

# %%
df.iloc[3:]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# ...

# %% [markdown]
# ### Step 20. Select every row up to the 4th row

# %%
df.iloc[:3]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %% [markdown]
# ### Step 21. Select the 3rd column up to the 7th column

# %%
# the first : means all
# after the comma you select the range

df.iloc[: , 4:7]
# Out:
#       LotArea Street Alley
# 0        8450   Pave   NaN
# 1        9600   Pave   NaN
# 2       11250   Pave   NaN
# 3        9550   Pave   NaN
# 4       14260   Pave   NaN
# 5       14115   Pave   NaN
# 6       10084   Pave   NaN
# 7       10382   Pave   NaN
# 8        6120   Pave   NaN
# 9        7420   Pave   NaN
# 10      11200   Pave   NaN
# 11      11924   Pave   NaN
# 12      12968   Pave   NaN
# 13      10652   Pave   NaN
# 14      10920   Pave   NaN
# 15       6120   Pave   NaN
# 16      11241   Pave   NaN
# 17      10791   Pave   NaN
# 18      13695   Pave   NaN
# 19       7560   Pave   NaN
# 20      14215   Pave   NaN
# 21       7449   Pave  Grvl
# 22       9742   Pave   NaN
# 23       4224   Pave   NaN
# 24       8246   Pave   NaN
# 25      14230   Pave   NaN
# 26       7200   Pave   NaN
# 27      11478   Pave   NaN
# 28      16321   Pave   NaN
# 29       6324   Pave   NaN
# ...       ...    ...   ...
# 1430    21930   Pave   NaN
# 1431     4928   Pave   NaN
# ...

# %% [markdown]
# ### Step 14. Select rows where df.LotFrontage is greater than 50

# %%
df[df['LotFrontage'] > 50]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# ...

# %% [markdown]
# ### Step 14. Select rows where df.LotFrontage is greater than 500 or less than 50

# %%
df[(df['LotFrontage'] > 500) | (df['LotFrontage'] < 50)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 46      47          50       RL         48.0    12822   Pave   NaN      IR1
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 56      57         160       FV         24.0     2645   Pave  Pave      Reg
# 62      63         120       RL         44.0     6442   Pave   NaN      IR1
# 68      69          30       RM         47.0     4608   Pave   NaN      Reg
# 75      76         180       RM         21.0     1596   Pave   NaN      Reg
# 81      82         120       RM         32.0     4500   Pave   NaN      Reg
# 87      88         160       FV         40.0     3951   Pave  Pave      Reg
# 115    116         160       FV         34.0     3230   Pave  Pave      Reg
# ...

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
df[(df['SaleCondition'] != 'Abnorml')]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# ...
